# %% [markdown]
# # 🌐 6.4 – Serialización de Datos con JSON y XML
#
# En este notebook aprenderás a representar y persistir datos estructurados usando dos formatos muy comunes:
#
# - **JSON** → ligero, legible y usado en APIs y web.
# - **XML** → jerárquico, usado en configuraciones y documentos.
#
# Ambos permiten **guardar estructuras de datos** (listas, diccionarios, objetos) y volver a cargarlas fácilmente.

# %%
print('✅ Notebook 6.4 – Serialización con JSON y XML cargado correctamente.')

# %% [markdown]
# ---
# ## 🎯 Objetivos
# - Serializar y deserializar objetos Python a JSON y XML.
# - Comprender las diferencias entre ambos formatos.
# - Manipular archivos JSON reales y generar XML programáticamente.
# - Practicar la lectura, escritura y modificación de datos estructurados.

# %% [markdown]
# ---
# ## 1️⃣ Serialización con JSON
#
# El formato **JSON (JavaScript Object Notation)** es el más usado para intercambiar datos entre aplicaciones web y APIs.
#
# En Python se maneja con el módulo estándar `json`.

# %%
import json

usuario = {
    'nombre': 'Ana',
    'edad': 30,
    'activo': True,
    'habilidades': ['Python', 'SQL', 'Docker']
}

with open('usuario.json', 'w', encoding='utf-8') as f:
    json.dump(usuario, f, indent=4, ensure_ascii=False)

print('✅ Archivo JSON generado correctamente.')

# %% [markdown]
# ✅ `indent=4` mejora la legibilidad y `ensure_ascii=False` conserva caracteres especiales (acentos, ñ...).

# %% [markdown]
# ---
# ## 2️⃣ Leer JSON desde un archivo
#
# Usamos `json.load()` para convertir el contenido nuevamente a un objeto Python.

# %%
with open('usuario.json', 'r', encoding='utf-8') as f:
    datos = json.load(f)

print('📦 Datos cargados desde JSON:')
print(datos)

# %% [markdown]
# ✅ Observa que se reconstruye exactamente la estructura original (`dict`, `list`, `bool`, etc.).

# %% [markdown]
# ---
# ## 3️⃣ 🧩 Ejercicio 1 — Guardar lista de productos en JSON
#
# Crea una lista de productos con nombre, precio y stock. Guarda el contenido en `productos.json` y luego vuelve a cargarlo mostrando solo los productos con **precio > 50**.
#
# 💡 *Pista:* usa `json.dump()` y `json.load()` con comprensión de listas para filtrar los resultados.

# %%
# Escribe aquí tu solución...

# %% [markdown]
# ### ✅ Solución propuesta

# %%
productos = [
    {'nombre': 'Monitor', 'precio': 120, 'stock': 5},
    {'nombre': 'Teclado', 'precio': 45, 'stock': 10},
    {'nombre': 'Ratón', 'precio': 25, 'stock': 15}
]

with open('productos.json', 'w', encoding='utf-8') as f:
    json.dump(productos, f, indent=4, ensure_ascii=False)

with open('productos.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

caros = [p for p in data if p['precio'] > 50]
print('💰 Productos caros:', caros)

# %% [markdown]
# ---
# ## 4️⃣ Serialización con XML
#
# El módulo `xml.etree.ElementTree` permite **crear, leer y escribir documentos XML**.
#
# Ejemplo: generar un archivo con datos de usuarios.

# %%
import xml.etree.ElementTree as ET

root = ET.Element('usuarios')
user = ET.SubElement(root, 'usuario', id='1')
ET.SubElement(user, 'nombre').text = 'Ana'
ET.SubElement(user, 'edad').text = '30'
ET.SubElement(user, 'activo').text = 'True'

tree = ET.ElementTree(root)
tree.write('usuarios.xml', encoding='utf-8', xml_declaration=True)

print('✅ Archivo XML generado correctamente.')

# %% [markdown]
# ✅ Cada nodo se crea con `ET.SubElement()` y se asigna texto o atributos según sea necesario.

# %% [markdown]
# ---
# ## 5️⃣ Leer XML desde archivo
#
# Podemos parsear el XML y recorrer sus elementos fácilmente:

# %%
tree = ET.parse('usuarios.xml')
root = tree.getroot()

for user in root.findall('usuario'):
    nombre = user.find('nombre').text
    edad = user.find('edad').text
    print(f'👤 {nombre}, {edad} años')

# %% [markdown]
# ✅ `find()` y `findall()` permiten acceder fácilmente a nodos dentro de la jerarquía XML.

# %% [markdown]
# ---
# ## 6️⃣ 🧩 Ejercicio 2 — Generar XML de productos
#
# Crea un XML llamado `inventario.xml` con varios productos (nombre, precio, stock). Luego léelo y muestra los productos con stock inferior a 10.
#
# 💡 *Pista:* usa `ET.SubElement()` para cada campo y `.find()` para acceder al valor del stock.

# %%
# Implementa tu solución aquí...

# %% [markdown]
# ### ✅ Solución propuesta

# %%
root = ET.Element('inventario')

productos = [
    {'nombre': 'Monitor', 'precio': 120, 'stock': 5},
    {'nombre': 'Teclado', 'precio': 45, 'stock': 12},
    {'nombre': 'Ratón', 'precio': 25, 'stock': 8}
]

for p in productos:
    item = ET.SubElement(root, 'producto')
    ET.SubElement(item, 'nombre').text = p['nombre']
    ET.SubElement(item, 'precio').text = str(p['precio'])
    ET.SubElement(item, 'stock').text = str(p['stock'])

tree = ET.ElementTree(root)
tree.write('inventario.xml', encoding='utf-8', xml_declaration=True)

tree = ET.parse('inventario.xml')
root = tree.getroot()

print('📦 Productos con stock < 10:')
for item in root.findall('producto'):
    nombre = item.find('nombre').text
    stock = int(item.find('stock').text)
    if stock < 10:
        print(f'- {nombre}: {stock}')

# %% [markdown]
# ---
# ## 7️⃣ 🧠 Resumen del notebook
#
# - **JSON**: ligero, universal, ideal para APIs y datos web.
# - **XML**: jerárquico, útil en configuraciones y estructuras anidadas.
# - Ambos permiten guardar y restaurar estructuras Python.
# - `json.dump()` y `ET.ElementTree()` son las herramientas base.
#
# 💡 Próximo paso → **6.5 – Laboratorio: Configuración de Usuario y Preferencias.**
