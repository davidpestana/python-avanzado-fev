# %% [markdown]
# # 🌐 8.2 — Gráficos Dinámicos con Plotly
#
# En este notebook aprenderás a crear **gráficos interactivos** con la librería **Plotly Express**.
#
# Plotly permite generar dashboards y visualizaciones dinámicas que se pueden explorar, acercar, filtrar y exportar.
#
# 💡 *Objetivo:* representar datos con interactividad y estilos profesionales.

# %%
import pandas as pd
import numpy as np
import plotly.express as px

print('✅ Notebook 8.2 — Plotly Express cargado correctamente.')
# Out:
# ✅ Notebook 8.2 — Plotly Express cargado correctamente.

# %% [markdown]
# ---
# ## 1️⃣ Cargar y preparar el dataset
#
# Usaremos nuevamente el dataset `ventas.csv`, adaptando nombres y calculando métricas básicas.

# %%
df = pd.read_csv('../../datasets/ventas.csv')
df.rename(columns={'cantidad': 'unidades', 'precio': 'precio_unitario'}, inplace=True)
df['fecha'] = pd.to_datetime(df['fecha'])
df['ingresos'] = df['unidades'] * df['precio_unitario']
df.head()
# Out:
#        fecha producto  unidades  precio_unitario  ingresos
# 0 2025-10-01        A        10              5.2      52.0
# 1 2025-10-01        B         4              7.1      28.4
# 2 2025-10-02        A         6              5.0      30.0
# 3 2025-10-02        C         9              3.9      35.1
# 4 2025-10-03        B         7              7.2      50.4

# %% [markdown]
# ---
# ## 2️⃣ Gráfico de barras interactivo — Ingresos por producto
#
# Plotly Express permite generar gráficos complejos con una sola línea de código.

# %%
fig = px.bar(
    df, x='producto', y='ingresos', color='producto',
    title='Ingresos totales por producto',
    labels={'producto': 'Producto', 'ingresos': 'Ingresos (€)'},
    hover_data=['unidades', 'precio_unitario'],
    color_discrete_sequence=px.colors.qualitative.Vivid
)
fig.update_layout(template='plotly_white')
fig.show()

# %% [markdown]
# ✅ Puedes pasar el ratón para ver valores exactos, hacer zoom o exportar el gráfico como imagen o HTML.

# %% [markdown]
# ---
# ## 3️⃣ 🧩 Ejercicio — Evolución temporal de los ingresos totales
#
# Usa un **gráfico de líneas interactivo (`px.line`)** para mostrar la evolución de ingresos por fecha.
#
# 👉 *Pista:* agrupa por `fecha` y suma los ingresos antes de graficar.

# %%
# ✏️ Tu código aquí...

# %% [markdown]
# ### ✅ Solución propuesta

# %%
ingresos_dia = df.groupby('fecha', as_index=False)['ingresos'].sum()

fig = px.line(
    ingresos_dia, x='fecha', y='ingresos', markers=True,
    title='Evolución de ingresos diarios',
    labels={'fecha': 'Fecha', 'ingresos': 'Ingresos (€)'},
    color_discrete_sequence=['royalblue']
)
fig.update_traces(line=dict(width=3))
fig.update_layout(template='plotly_white')
fig.show()

# %% [markdown]
# ---
# ## 4️⃣ Gráfico de dispersión — Precio vs Unidades
#
# Podemos analizar la relación entre variables numéricas de forma interactiva.

# %%
fig = px.scatter(
    df, x='precio_unitario', y='unidades', color='producto',
    size='ingresos', hover_name='producto',
    title='Relación entre precio, unidades e ingresos',
    color_discrete_sequence=px.colors.qualitative.Bold
)
fig.update_layout(template='plotly_white')
fig.show()

# %% [markdown]
# ✅ El tamaño de las burbujas representa los ingresos generados por cada producto.

# %% [markdown]
# ---
# ## 5️⃣ �� Ejercicio — Ingresos por producto y fecha
#
# Crea un gráfico de líneas donde cada **producto** sea una serie distinta.
#
# 👉 *Pista:* usa `color='producto'` dentro de `px.line()`.

# %%
# 🧩 Escribe tu código aquí...

# %% [markdown]
# ### ✅ Solución propuesta

# %%
ingresos_prod_dia = df.groupby(['fecha', 'producto'], as_index=False)['ingresos'].sum()

fig = px.line(
    ingresos_prod_dia, x='fecha', y='ingresos', color='producto', markers=True,
    title='Ingresos diarios por producto',
    labels={'fecha': 'Fecha', 'ingresos': 'Ingresos (€)', 'producto': 'Producto'},
    color_discrete_sequence=px.colors.qualitative.Set2
)
fig.update_layout(template='plotly_white')
fig.show()

# %% [markdown]
# ---
# ## 6️⃣ Gráfico circular — Participación de productos
#
# Para representar proporciones, Plotly incluye `px.pie()`.

# %%
participacion = df.groupby('producto', as_index=False)['ingresos'].sum()
fig = px.pie(
    participacion, values='ingresos', names='producto',
    title='Participación de productos en los ingresos',
    color_discrete_sequence=px.colors.qualitative.Pastel
)
fig.update_traces(textinfo='percent+label', pull=[0, 0.05, 0.05, 0.1])
fig.show()

# %% [markdown]
# ---
# ## 7️⃣ Exportar gráficos a HTML
#
# Podemos guardar cualquier gráfico de Plotly como un archivo HTML totalmente interactivo:

# %%
# fig.write_html('grafico_ingresos.html')
# print('✅ Archivo exportado: grafico_ingresos.html')

# %% [markdown]
# ---
# ## 8️⃣ 🧠 Conclusiones
#
# - Plotly Express permite construir gráficos interactivos de forma simple.
# - Ideal para dashboards y notebooks analíticos.
# - Puede integrarse fácilmente con **Dash** para crear aplicaciones web interactivas.
#
# �� Próximo paso → **8.3 — Laboratorio: Dashboard Interactivo de Ventas.**
