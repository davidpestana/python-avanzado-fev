# %% [markdown]
# # 🧩 5.1 – Funciones Lambda y Comprensiones en Python
#
# En este notebook exploraremos dos de los elementos más potentes del estilo **funcional** en Python:
#
# - **Funciones lambda:** funciones anónimas y expresivas para operaciones simples.
# - **Comprensiones:** construcciones sintácticas que permiten crear listas, conjuntos y diccionarios de forma declarativa.
#
# ---
# ## 🎯 Objetivos
# - Comprender el uso y limitaciones de las funciones lambda.
# - Escribir código compacto usando comprensiones.
# - Crear estructuras derivadas de otras colecciones sin bucles explícitos.
# - Combinar lambdas y comprensiones para transformar datos.

# %%
print('✅ Notebook 5.1 – Lambda y Comprensiones listo para usar.')

# %% [markdown]
# ---
# ## 1️⃣ Funciones lambda: definición y uso básico
#
# Las **funciones lambda** son funciones anónimas, es decir, sin nombre. Se usan para operaciones pequeñas o temporales.
#
# ```python
# lambda argumentos: expresión
# ```
#
# Ejemplo básico:

# %%
doble = lambda x: x * 2
print(doble(5))  # 10

# %% [markdown]
# ✅ Una lambda siempre devuelve el resultado de la expresión, **sin usar `return`**.

# %% [markdown]
# ---
# ## 2️⃣ Uso práctico: ordenar y filtrar con lambdas
#
# Podemos usar lambdas junto con funciones como `sorted()` o `filter()` para simplificar código:

# %%
nombres = ['Ana', 'bernardo', 'Carlos', 'david']
ordenados = sorted(nombres, key=lambda n: n.lower())
print(ordenados)

# %% [markdown]
# ✅ `key=lambda n: n.lower()` convierte todos los nombres a minúsculas antes de comparar, logrando una ordenación insensible a mayúsculas.

# %% [markdown]
# ---
# ## 3️⃣ 🧩 Ejercicio 1 — Lambda como filtro
#
# Crea una lista `numeros = [3, 8, 15, 22, 7, 5, 19]` y usa `filter()` con una función lambda para obtener solo los números **mayores que 10**.
#
# 💡 *Pista:* `filter(lambda x: condición, iterable)` devuelve un iterador, conviértelo con `list()`.

# %%
# Escribe tu código aquí...

# %% [markdown]
# ### ✅ Solución propuesta

# %%
numeros = [3, 8, 15, 22, 7, 5, 19]
mayores_10 = list(filter(lambda x: x > 10, numeros))
print(mayores_10)

# %% [markdown]
# ---
# ## 4️⃣ Comprensiones de listas
#
# Las **comprensiones** permiten crear listas nuevas a partir de otras colecciones en una sola línea.
#
# ### Sintaxis básica
# ```python
# [expresión for elemento in iterable if condición]
# ```
#
# Ejemplo:

# %%
numeros = [1, 2, 3, 4, 5]
cuadrados = [n**2 for n in numeros]
print(cuadrados)

# %% [markdown]
# ✅ Es equivalente a usar un bucle for, pero más legible y eficiente.

# %% [markdown]
# ---
# ## 5️⃣ 🧩 Ejercicio 2 — Filtrar y transformar
#
# Dada la lista `temperaturas = [18, 25, 30, 12, 28, 21]`, crea una nueva lista con las temperaturas en **grados Fahrenheit** solo si son **mayores o iguales a 20°C**.
#
# 💡 Fórmula: `F = C * 9/5 + 32`

# %%
# Escribe aquí tu comprensión de lista...

# %% [markdown]
# ### ✅ Solución propuesta

# %%
temperaturas = [18, 25, 30, 12, 28, 21]
fahrenheit = [t * 9/5 + 32 for t in temperaturas if t >= 20]
print(fahrenheit)

# %% [markdown]
# ---
# ## 6️⃣ Comprensiones de conjuntos y diccionarios
#
# También podemos construir **sets** o **dicts** con comprensiones:
#
# ### Set comprehension
# ```python
# {expresión for elemento in iterable}
# ```
#
# ### Dict comprehension
# ```python
# {clave: valor for elemento in iterable}
# ```

# %%
palabras = ['python', 'java', 'python', 'go', 'java', 'c++']
unicos = {p for p in palabras}  # set comprehension
longitudes = {p: len(p) for p in unicos}  # dict comprehension

print(unicos)
print(longitudes)

# %% [markdown]
# ✅ Los conjuntos eliminan duplicados automáticamente y los diccionarios permiten asociar claves con valores derivados.

# %% [markdown]
# ---
# ## 7️⃣ 🧩 Ejercicio 3 — Diccionario de cuadrados pares
#
# Crea un **diccionario** que contenga los números pares del 0 al 10 como claves y sus cuadrados como valores.
#
# 💡 Usa comprensión de diccionario con una condición (`if`).

# %%
# Escribe aquí tu código...

# %% [markdown]
# ### ✅ Solución propuesta

# %%
cuadrados_pares = {n: n**2 for n in range(11) if n % 2 == 0}
print(cuadrados_pares)

# %% [markdown]
# ---
# ## 🧠 Resumen del notebook
#
# - Las **lambdas** son funciones pequeñas e inmutables, útiles con `map`, `filter`, `sorted`.
# - Las **comprensiones** permiten generar colecciones nuevas de forma declarativa.
# - Se pueden anidar y combinar con condiciones.
# - Las **dict comprehensions** y **set comprehensions** amplían las posibilidades.
#
# �� Próximo paso → **5.2 – zip(), any() y all(): funciones funcionales integradas.**
