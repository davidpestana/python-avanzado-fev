# %% [markdown]
# # 🧩 2.1 – Listas, Tuplas, Diccionarios y Sets
#
# En este notebook exploraremos las **principales colecciones nativas** de Python:
#
# - `list`: listas ordenadas y mutables.
# - `tuple`: tuplas ordenadas e inmutables.
# - `dict`: diccionarios clave–valor.
# - `set`: conjuntos sin duplicados.
#
# Cada una tiene propiedades, métodos y usos específicos en el procesamiento de datos.
#
# ---
# ## 🎯 Objetivos
# - Comprender la estructura, mutabilidad y uso de cada tipo.
# - Aprender operaciones comunes (agregar, eliminar, recorrer, filtrar).
# - Comparar rendimiento y casos de uso.
# - Usar comprensiones para construir colecciones rápidamente.

# %%
print('✅ Colecciones en Python listas para explorar.')

# %% [markdown]
# ---
# ## 1️⃣ Listas (`list`)
#
# Las listas son **colecciones ordenadas y mutables**. Permiten almacenar cualquier tipo de elemento, incluso mezclado.

# %%
frutas = ['manzana', 'pera', 'naranja']
print(frutas)

# Acceso y modificación
frutas[1] = 'plátano'
frutas.append('kiwi')
print(frutas)

# %% [markdown]
# ✅ Métodos comunes: `append`, `insert`, `remove`, `pop`, `sort`, `reverse`.
#
# 👉 Las listas son ideales para colecciones ordenadas y modificables.

# %% [markdown]
# ---
# ## 2️⃣ Tuplas (`tuple`)
#
# Las tuplas son **inmutables**: una vez creadas, no se pueden modificar. Son más ligeras y seguras para datos fijos.

# %%
coordenadas = (10, 20)
print(coordenadas)

# coordenadas[0] = 99  # ❌ Error: las tuplas no se pueden modificar
print(len(coordenadas))

# %% [markdown]
# ✅ Las tuplas se usan frecuentemente para **devolver múltiples valores** de una función o como claves de diccionario.

# %% [markdown]
# ---
# ## 3️⃣ Diccionarios (`dict`)
#
# Colecciones **clave → valor**. Muy utilizados para representar datos estructurados (como registros o JSON).

# %%
persona = {
    'nombre': 'Ana',
    'edad': 30,
    'ciudad': 'Valencia'
}
print(persona)

# Acceso y actualización
persona['edad'] = 31
persona['profesion'] = 'ingeniera'
print(persona)

# %% [markdown]
# ✅ Métodos comunes: `keys()`, `values()`, `items()`, `get()`, `update()`.
#
# 👉 Son mutables y rápidos para búsquedas por clave.

# %% [markdown]
# ---
# ## 4️⃣ Conjuntos (`set`)
#
# Colecciones **no ordenadas y sin duplicados**. Útiles para eliminar repetidos o realizar operaciones matemáticas de conjuntos.

# %%
colores = {'rojo', 'verde', 'azul', 'rojo'}
print(colores)  # Elimina duplicados automáticamente

otros = {'azul', 'negro'}
print('Unión:', colores | otros)
print('Intersección:', colores & otros)
print('Diferencia:', colores - otros)

# %% [markdown]
# ✅ Muy útiles para comparar colecciones o eliminar duplicados de una lista con `set(lista)`.

# %% [markdown]
# ---
# ## 5️⃣ Comparativa rápida
#
# | Tipo | Ordenado | Mutable | Duplicados | Sintaxis |
# |:----:|:----------:|:----------:|:-------------:|:----------:|
# | `list` | ✅ | ✅ | ✅ | `[ ]` |
# | `tuple` | ✅ | ❌ | ✅ | `( )` |
# | `dict` | ✅ (3.7+) | ✅ | ❌ claves únicas | `{ clave: valor }` |
# | `set` | ❌ | ✅ | ❌ | `{ }` |
#
# ---
# ## 6️⃣ Ejercicio práctico
#
# Dada la siguiente lista:
# ```python
# nombres = ['ana', 'luis', 'ana', 'pepe', 'luis', 'maria']
# ```
# Crea un programa que:
# 1. Muestre los nombres únicos.
# 2. Cree un diccionario con el número de repeticiones.
# 3. Lo ordene por frecuencia descendente.

# %%
nombres = ['ana', 'luis', 'ana', 'pepe', 'luis', 'maria']
unicos = set(nombres)
conteo = {n: nombres.count(n) for n in unicos}
ordenado = dict(sorted(conteo.items(), key=lambda x: x[1], reverse=True))
print(ordenado)

# %% [markdown]
# ---
# ## 🧠 Resumen del notebook
#
# - `list`: estructura flexible y mutable.
# - `tuple`: versión inmutable para datos fijos.
# - `dict`: clave–valor, ideal para estructuras complejas.
# - `set`: conjunto sin duplicados, útil para operaciones matemáticas.
#
# 💡 Dominar estas colecciones es esencial para todo el trabajo con datos en Python.
